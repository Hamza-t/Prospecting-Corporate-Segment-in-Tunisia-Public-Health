# %%
import pandas as pd

# %%
#drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#verify the path
data_path = "/content/drive/MyDrive/My_work/Siwar_internship"

# %%
# !ls "/content/drive/MyDrive/My_work/Siwar_internship"
# Out:
# 'Dentists analysis'  'Doctors analysis'  'Pharmacis analysis'

# %%
#read data 

data = pd.read_csv(data_path+"/"+"Doctors analysis/doctors.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  index                                  name  \
# 0           0      0  Dr. Harhira Mohamed Abderraouf - Orl
# 1           1      1                    Dr. Houcine Mnasri
# 2           2      2                    Dr. Ben Said Malek
# 3           3      3                       Dr. Sedki Rania
# 4           4      4                   Dr. Marzouk Mansour
#
#                speciality                                           map_link  \
# 0     orl et stomatologie  http://maps.google.com/?q=36.501578938529015,8...
# 1  anesthesie-reanimation  http://maps.google.com/?q=37.2872637875397,9.8...
# 2     orl et stomatologie     http://maps.google.com/?q=37.2767579,9.8641609
# 3       medecine generale  http://maps.google.com/?q=35.374552499565574,1...
# 4               sexologue  http://maps.google.com/?q=35.83409619286789,10...
#
#                                               adress                  local  \
# 0                                           Jendouba  Jendouba Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...   Bizerte Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Mahdia Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Sousse Jawhara
#
#                                  telephones
# 0  ['tel:+21678605200', 'tel:+21695343403']
# 1  ['tel:+21698714000', 'tel:+21672434444']
# 2  ['tel:+21672420421', 'tel:+21622808088']
# 3  ['tel:+21695429834', 'tel:+21699984281']
# 4                      ['tel:+21626404474']

# %%
#lets make some experince with data 
print(data["local"][0].split(" ")[0])
" ".join(data["local"][0].split(" ")[1:])
# Out:
# Jendouba
# 'Jendouba Sud'

# %%
 t= data["telephones"][1000]
 t.split("'")[1][4:]
# Out:
# '71891472'

# %%
data["adress"][1000].lower()
# Out:
# '108, rue de palestine'

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'index', 'name', 'speciality', 'map_link', 'adress',
#        'local', 'telephones'],
#       dtype='object')

# %%
#data cleaning 
data = data[["name","speciality","adress","local","telephones"]]

# %%
data.head()
# Out:
#                                    name              speciality  \
# 0  Dr. Harhira Mohamed Abderraouf - Orl     orl et stomatologie
# 1                    Dr. Houcine Mnasri  anesthesie-reanimation
# 2                    Dr. Ben Said Malek     orl et stomatologie
# 3                       Dr. Sedki Rania       medecine generale
# 4                   Dr. Marzouk Mansour               sexologue
#
#                                               adress                  local  \
# 0                                           Jendouba  Jendouba Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...   Bizerte Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Mahdia Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Sousse Jawhara
#
#                                  telephones
# 0  ['tel:+21678605200', 'tel:+21695343403']
# 1  ['tel:+21698714000', 'tel:+21672434444']
# 2  ['tel:+21672420421', 'tel:+21622808088']
# 3  ['tel:+21695429834', 'tel:+21699984281']
# 4                      ['tel:+21626404474']

# %%
#Cleaning 
#ville
def ville(t):
  t = str(t)
  return " ".join(t.split(" ")[1:])

#gouvernorat
def gouvernorat(t):
  t = str(t)
  return t.split(" ")[0]

#telephone
def phone1(t):
  t=str(t)
  tr = t.split("'")
  if len(tr)>1: 
    return tr[1][4:]
  else : return 0


def phone2(t):
  t=str(t)
  tr = t.split("'")
  if len(tr)>3: 
    return tr[3][4:]
  else : return 0




t= data["telephones"][0]
t.split("'")[3][4:]

data["ville"] = data["local"].apply(ville)
data["gouvernorat"] = data["local"].apply(gouvernorat)


data["phone 1"] = data["telephones"].apply(phone1)
data["phone 2"] = data["telephones"].apply(phone2)

# %%
st= list(data['local'])
for i in st : 
  if type(i) == 'float':
    print("haaa")

# %%
type(30.)
# Out:
# float

# %%
data.head()
# Out:
#                                    name              speciality  \
# 0  Dr. Harhira Mohamed Abderraouf - Orl     orl et stomatologie
# 1                    Dr. Houcine Mnasri  anesthesie-reanimation
# 2                    Dr. Ben Said Malek     orl et stomatologie
# 3                       Dr. Sedki Rania       medecine generale
# 4                   Dr. Marzouk Mansour               sexologue
#
#                                               adress                  local  \
# 0                                           Jendouba  Jendouba Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...   Bizerte Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Mahdia Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Sousse Jawhara
#
#                                  telephones           ville gouvernorat  \
# 0  ['tel:+21678605200', 'tel:+21695343403']    Jendouba Sud    Jendouba
# 1  ['tel:+21698714000', 'tel:+21672434444']    Ariana Ville      Ariana
# 2  ['tel:+21672420421', 'tel:+21622808088']    Bizerte Nord     Bizerte
# 3  ['tel:+21695429834', 'tel:+21699984281']    Sidi Alouane      Mahdia
# 4                      ['tel:+21626404474']  Sousse Jawhara      Sousse
#
#         phone 1
# 0  +21678605200
# 1  +21698714000
# 2  +21672420421
# 3  +21695429834
# 4  +21626404474

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#                                    name              speciality  \
# 0  Dr. Harhira Mohamed Abderraouf - Orl     orl et stomatologie
# 1                    Dr. Houcine Mnasri  anesthesie-reanimation
# 2                    Dr. Ben Said Malek     orl et stomatologie
# 3                       Dr. Sedki Rania       medecine generale
# 4                   Dr. Marzouk Mansour               sexologue
#
#                                               adress                  local  \
# 0                                           Jendouba  Jendouba Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...   Bizerte Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Mahdia Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Sousse Jawhara
#
#                                  telephones           ville gouvernorat  \
# 0  ['tel:+21678605200', 'tel:+21695343403']    Jendouba Sud    Jendouba
# 1  ['tel:+21698714000', 'tel:+21672434444']    Ariana Ville      Ariana
# 2  ['tel:+21672420421', 'tel:+21622808088']    Bizerte Nord     Bizerte
# 3  ['tel:+21695429834', 'tel:+21699984281']    Sidi Alouane      Mahdia
# 4                      ['tel:+21626404474']  Sousse Jawhara      Sousse
#
#         phone 1       phone 2
# 0  +21678605200  +21695343403
# 1  +21698714000  +21672434444
# 2  +21672420421  +21622808088
# 3  +21695429834  +21699984281
# 4  +21626404474             0

# %%
data = data[['name',"speciality",'adress','ville','gouvernorat','phone 1','phone 2']]

# %%
data.head()
# Out:
#                                    name              speciality  \
# 0  Dr. Harhira Mohamed Abderraouf - Orl     orl et stomatologie
# 1                    Dr. Houcine Mnasri  anesthesie-reanimation
# 2                    Dr. Ben Said Malek     orl et stomatologie
# 3                       Dr. Sedki Rania       medecine generale
# 4                   Dr. Marzouk Mansour               sexologue
#
#                                               adress           ville  \
# 0                                           Jendouba    Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...    Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Jawhara
#
#   gouvernorat       phone 1       phone 2
# 0    Jendouba  +21678605200  +21695343403
# 1      Ariana  +21698714000  +21672434444
# 2     Bizerte  +21672420421  +21622808088
# 3      Mahdia  +21695429834  +21699984281
# 4      Sousse  +21626404474             0

# %%
data.columns = ['name',"speciality",'adress','City','governorate','phone 1','phone 2']

# %%
data.head()
# Out:
#                                    name              speciality  \
# 0  Dr. Harhira Mohamed Abderraouf - Orl     orl et stomatologie
# 1                    Dr. Houcine Mnasri  anesthesie-reanimation
# 2                    Dr. Ben Said Malek     orl et stomatologie
# 3                       Dr. Sedki Rania       medecine generale
# 4                   Dr. Marzouk Mansour               sexologue
#
#                                               adress            City  \
# 0                                           Jendouba    Jendouba Sud
# 1   153 avenue habib bourguiba- hippocenter- BIZERTE    Ariana Ville
# 2  Rue d'espagne, immeuble lido, Bizerte, 4ème ét...    Bizerte Nord
# 3  Place de l'indépendance , Sidi Alouane 5190 (e...    Sidi Alouane
# 4  bureau A 10 immeuble city center - charchari -...  Sousse Jawhara
#
#   governorate       phone 1       phone 2
# 0    Jendouba  +21678605200  +21695343403
# 1      Ariana  +21698714000  +21672434444
# 2     Bizerte  +21672420421  +21622808088
# 3      Mahdia  +21695429834  +21699984281
# 4      Sousse  +21626404474             0

# %%
from pathlib import Path  
filepath = Path('/content/drive/MyDrive/My_work/Siwar_internship/Doctors analysis/cleaned data/medecin.csv') 
filepath2 = Path('/content/drive/MyDrive/My_work/Siwar_internship/Doctors analysis/cleaned data/medecin.xlsx') 
data.to_csv(filepath)
data.to_excel(filepath2)
